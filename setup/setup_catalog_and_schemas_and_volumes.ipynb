# %%
# %sql
CREATE CATALOG IF NOT EXISTS pulsestream;
CREATE SCHEMA IF NOT EXISTS pulsestream.bronze;
CREATE SCHEMA IF NOT EXISTS pulsestream.silver;
CREATE SCHEMA IF NOT EXISTS pulsestream.gold;
CREATE VOLUME IF NOT EXISTS pulsestream.bronze._internal;
CREATE VOLUME IF NOT EXISTS pulsestream.silver._internal;
CREATE VOLUME IF NOT EXISTS pulsestream.gold._internal;
